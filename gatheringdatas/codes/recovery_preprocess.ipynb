# %% [markdown]
# ## recovery 전처리 시작

# %%
# !pip install --user python-mecab-ko pyLDAvis

# %% [markdown]
# ### 쿠팡이랑 11번가 댓글 합치기

# %%
import pandas as pd

# %%
# df_recover_coup=pd.read_csv('../datasets/recovery_coupang.csv')
# df_recover_11st=pd.read_csv('../datasets/recovery_eleven.csv')

# %%
# df_recovery_raw=pd.concat([df_recover_coup, df_recover_11st], axis=0)
# df_recovery_raw

# %%
# df_recovery_raw.isnull().sum()

# %%
# df_recovery_raw=df_recovery_raw.dropna()

# %%
# df_recovery_raw

# %%
# df_recovery_raw=df_recovery_raw.drop(columns=['Unnamed: 0','_id'])

# %%
# df_recovery = df_recovery_raw.reset_index(drop=True)
# df_recovery

# %%
# df_recovery.to_csv('../datasets/recovery.csv')
df_recovery=pd.read_csv('../datasets/recovery.csv')

# %%
df_recovery=df_recovery.drop(columns=['Unnamed: 0'])

# %% [markdown]
# ### 불용어 처리 및 한글자 살리기 및 단어 치환,

# %% [markdown]
# #### 전처리 필요한 파일들 가져오기

# %%
# 대체어
df_replace = pd.read_excel('../datasets/sa_replace_list.xlsx')
df_replace[:5]
# Out:
#   before_replacement after_replacement
# 0                만졷ㄱ                만족
# 1               않좋아서              안좋아서
# 2               괜찮네요             보통이예요
# 3                시킬껭              시킬게요
# 4                  용                 요

# %%
# 불용어 
df_stop = pd.read_excel('../datasets/sa_stopword_list.xlsx')
df_stop[:5]
# Out:
#   stopword
# 0     가까스로
# 1       가량
# 2       가령
# 3       가민
# 4    가민커넥트

# %%
# 한글자 살리기
df_oneword=pd.read_excel('../datasets/sa_one_char_list.xlsx')
df_oneword[:5]
# Out:
#   one_char_keyword
# 0                컵
# 1                방
# 2                물
# 3                돈
# 4                꿈

# %% [markdown]
# #### 전처리 시작
# - 1. 단어 치환 하기
# - 2. 불용어 처리 하기
# - 3. okt 이용해서 stemming 하기 _ 부사를 동사 원형으로 바꿔서 보기
# <!-- mecab.pos로 토큰화하기 (.append(' '.join(token)) okt 하기  -->

# %%
## 단어 치환 함수 블로그 복사
def replace_word(review):
    for number in range(len(df_replace['before_replacement'])):
        try: 
            # 치환 단어만 데이터 치환
            if replace_list['before_replacement'][number] in review_content :
                review_content = review.replace(replace_list['before_replacement'][number], replace_list['after_replacement'][number])
        except: 
            pass
    return review

# %%
## 단어 치환 함수 블로그 복사
df_recovery['reveiw_replaced'] = ''
review_replaced_list = list()
for review in df_recovery['review_content']:
    review_replaced = replace_word(str(review))
    review_replaced_list.append(review_replaced)
df_recovery['reveiw_replaced'] = review_replaced_list
df_recovery[-10:]
# Out:
#                                 product_name review_date  \
# 21764  푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.09.23
# 21765  푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.03.03
# 21766  푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.02.27
# 21767  푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.02.27
# 21768  푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.08.09
# 21769  푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.07.15
# 21770  푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.07.07
# 21771  푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.06.16
# 21772  푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.04.06
# 21773  푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.03.27
#
#                                           review_content  review_star  \
# 21764  배송 빨라요 성능 보통이에요 유통기한 보통이에요\n제품 섭취한지 얼마되지않아.좋은지...          3.0
# 21765  배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요\n아침마다 일어나는게 힘...          5.0
# 21766  배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요\n요즘 들어 기력이 떨어...          5.0
# 21767  배송 빨라요 성능 성능이 뛰어나요 유통기한 보통이에요\n지금까지 먹어본것중 아르기닌...          5.0
# 21768                   배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요          5.0
# 21769  배송 빨라요 성능 성능이 별로예요 유통기한 기한이 넉넉해요\n2박스 먹어봤으나 피로...          2.0
# 21770  배송 빨라요 성능 성능이 별로예요 유통기한 보통이에요\n호불호가 있을지 모르겠지만 ...          2.0
# 21771                   배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요          5.0
# 21772     배송 보통이에요 성능 보통이에요 유통기한 보통이에요\n지인 선물을줬는데  좋아했어요          5.0
# 21773                    배송 보통이에요 성능 성능이 뛰어나요 유통기한 보통이에요          5.0
#
#                review_writer  \
# 21764             jong******
# 21765               daph****
# 21766  neti*****************
# 21767            with*******
# 21768                 jhi8**
# 21769               rkdg****
# 21770   macg****************
# 21771               rkdg****
# 21772                    채슨생
# 21773                smcd***
#
#                                          reveiw_replaced
# 21764  배송 빨라요 성능 보통이에요 유통기한 보통이에요\n제품 섭취한지 얼마되지않아.좋은지...
# 21765  배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요\n아침마다 일어나는게 힘...
# 21766  배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요\n요즘 들어 기력이 떨어...
# 21767  배송 빨라요 성능 성능이 뛰어나요 유통기한 보통이에요\n지금까지 먹어본것중 아르기닌...
# 21768                   배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요
# 21769  배송 빨라요 성능 성능이 별로예요 유통기한 기한이 넉넉해요\n2박스 먹어봤으나 피로...
# 21770  배송 빨라요 성능 성능이 별로예요 유통기한 보통이에요\n호불호가 있을지 모르겠지만 ...
# 21771                   배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요
# 21772     배송 보통이에요 성능 보통이에요 유통기한 보통이에요\n지인 선물을줬는데  좋아했어요
# 21773                    배송 보통이에요 성능 성능이 뛰어나요 유통기한 보통이에요

# %%
# 내용의 토큰화 먼저_healthapp 복사
from mecab import MeCab
mecab = MeCab()
from konlpy.tag import Okt
okt = Okt()
stop=df_stop['stopword'].tolist()
oneword=df_oneword['one_char_keyword'].tolist()

# %%
# 불용어 제거 _ 블로그 및 chat
def stopword(text) :
    words = text.split() # text를 공백 기준으로 단어 분할한 뒤, 불용어 처리 진행 
    removed_words = [word for word in words if word not in stop]
    return ' '.join(removed_words)

# %%
## 불용어 처리 완료 
df_recovery['stopremoved_reviews']=df_recovery['reveiw_replaced'].apply(stopword)

# %%
from konlpy.tag import Okt

# Okt 형태소 분석기 인스턴스 생성
okt = Okt()

# 토큰화 결과를 담을 리스트 초기화
tokenized_reviews = []

# df_recovery['stopremoved_reviews'] 열의 각 텍스트에 대해 어구 추출 및 형태소 분석 수행
for review_text in df_recovery['stopremoved_reviews']:
    tokens = []
    try:
        # 어구 추출
        phrases = okt.phrases(review_text)
        
        # 추출된 어구에 대해 형태소 분석 및 원하는 품사(Noun, Verb, Adjective, Adverb, Exclamation, Determiner, Conjunction, Alpha) 선택
        for phrase in phrases:
            pos_result = okt.pos(phrase, norm=True, stem=True)
            for word, pos in pos_result:
                if pos in ['Noun', 'Verb', 'Adjective', 'Adverb', 'Exclamation', 'Determiner', 'Conjunction', 'Alpha']:
                    if len(word) > 1 or word in oneword:
                        tokens.append(word)
    except:
        pass
    tokenized_reviews.append(' '.join(tokens))

# %%
# tokenized_reviews를 df_recovery에 새로운 열로 추가
df_recovery['okt_reviews'] = tokenized_reviews

# %%
df_recovery['okt_reviews'][21769]
# Out:
# '배송 성능 성능 성능 별로 유통 기한 유통 기한 기한 박스 피로 회복 안되다 느낌 유통 기한 박스 피로 회복 느낌'

# %%
from collections import Counter

# 중복된 단어를 제거하는 함수 정의
def remove_duplicates(text):
    tokens = text.split()
    word_counts = Counter(tokens)
    unique_tokens = list(word_counts.keys())
    return ' '.join(unique_tokens)
# 중복된 단어를 제거한 결과를 새로운 열에 저장하고 기존 열을 덮어쓰려면 다음 코드를 사용할 수 있습니다.
df_recovery['okt_reviews'] = df_recovery['okt_reviews'].apply(remove_duplicates)

# %%
okt_token=df_recovery['okt_reviews']

# %%
# mecab_results = list()

# # df_recovery['tokenized_reviews'] 열의 각 텍스트에 대해 형태소 분석 수행
# for mecab_convert in okt_token:
#     try:
#         tokens = mecab.pos(mecab_convert)
#         mecab_results.append(tokens)
#     except:
#         pass

# # mecab_results: 위의 for문으로 mecab.pos하면 어떻게 나오는지 확인용.

# %%
## okt를 mecab으로 한번 더 
again_token = list()

# df_recovery['stopremoved_reviews'] 열의 각 텍스트에 대해 토큰화 수행
for review_text in df_recovery['okt_reviews']:
    add_tokens = []
    try:
        for word in mecab.pos(review_text):
            token, pos = word[0], word[1]
            if (len(token) > 1 or token in oneword) or (len(token) == 1 and pos in ['VV', 'VA']):
                add_tokens.append(token)
    except:
        pass
    again_token.append(' '.join(add_tokens))

# %%
df_recovery['mecab_reviews'] = again_token

# %%
df_recovery['mecab_reviews']
# Out:
# 0                                            피곤 느낌 물 삼키 고요
# 1                                      복용 한지 얼마 피로 회복 증강 좋
# 2                    함량 품질 좋 제품 구매 항상 부분 한약 체력 도움 부원 성분 신경
# 3                       업무 강도 인지 입맛 구매 성분 함량 알약 타입 먹 크기 넘김
# 4        코로나 확진 떨어지 컨디션 블랙 마카 남자 특화 양제 성분 흑마 늘 아르기닌 관문 ...
#                                ...
# 21769                       배송 성능 별로 유통 기한 박스 피로 회복 안 되 느낌
# 21770                           배송 성능 별로 유통 기한 보통 호불호 먹 포기
# 21771                                          배송 성능 유통 기한
# 21772                                 배송 보통 성능 유통 기한 지인 선물
# 21773                                       배송 보통 성능 유통 기한
# Name: mecab_reviews, Length: 21774, dtype: object

# %%
# 'mecab_reviews' 열의 모든 텍스트를 하나의 문자열로 결합
combined_text = ' '.join(df_recovery['mecab_reviews'])

# %%
from wordcloud import WordCloud

# %%
from collections import Counter

# %% [markdown]
# #### 토큰화 리뷰 빈도 계산

# %% [markdown]
# ###### 형태소의 빈도를 계산할때

# %%
from collections import Counter

# 단어 빈도수 카운트
word_counts = Counter(combined_text.split())

# %%
# 한글 폰트 경로 설정 (Windows 환경에 맞게 경로 수정)
font_path = 'C:/Windows/Fonts/malgun.ttf'

# 단어 빈도수 딕셔너리를 WordCloud에 전달
wordcloud = WordCloud(font_path=font_path, background_color='white')
wordcloud.generate_from_frequencies(word_counts)

# %%
wordcloud.words_
# Out:
# {'배송': 1.0,
#  '유통': 0.8682129678439642,
#  '기한': 0.8670268845545598,
#  '구매': 0.8062730627306273,
#  '먹': 0.7285187137585661,
#  '제품': 0.6593305218766473,
#  '효과': 0.6296784396415392,
#  '가격': 0.6039799683711122,
#  '비타민': 0.599103848181339,
#  '좋': 0.5598313125988402,
#  '건강': 0.5376910911966263,
#  '성능': 0.5060622034791776,
#  '양제': 0.4588824459673168,
#  '복용': 0.44030047443331577,
#  '포장': 0.41526093832366895,
#  '하': 0.4091987348444913,
#  '도움': 0.3940432261465472,
#  '섭취': 0.37190300474433313,
#  '보통': 0.3614918292040063,
#  '보': 0.3599103848181339,
#  '생각': 0.3286768581971534,
#  '성분': 0.3278861360042172,
#  '안': 0.32419609910384817,
#  '주문': 0.3148392198207696,
#  '알약': 0.30969952556668423,
#  '하루': 0.29810226673695306,
#  '후기': 0.28413284132841327,
#  '상태': 0.2816288877174486,
#  '구입': 0.25896151818661045,
#  '크기': 0.25830258302583026,
#  '되': 0.2422245651027939,
#  '추천': 0.23036373220875067,
#  '가지': 0.2140221402214022,
#  '정도': 0.2113863995782815,
#  '영양': 0.2051924090669478,
#  '아침': 0.20123879810226675,
#  '피로': 0.20097522403795468,
#  '느낌': 0.19280442804428044,
#  '필요': 0.1848972061149183,
#  '나이': 0.1841064839219821,
#  '넘김': 0.18081180811808117,
#  '상품': 0.18081180811808117,
#  '같': 0.17343173431734318,
#  '쿠팡': 0.16736953083816553,
#  '면역': 0.165392725355825,
#  '하나': 0.16341591987348444,
#  '정말': 0.1628887717448603,
#  '캡슐': 0.16275698471270428,
#  '위해': 0.1565629942013706,
#  '사람': 0.15629942013705853,
#  '함량': 0.15260938323668952,
#  '물': 0.15142329994728518,
#  '리뷰': 0.14786505007907222,
#  '시작': 0.14760147601476015,
#  '기능': 0.14575645756457564,
#  '피부': 0.14562467053241962,
#  '남편': 0.14536109646810755,
#  '다시': 0.1429889298892989,
#  '개월': 0.14272535582498683,
#  '회복': 0.14259356879283078,
#  '선물': 0.14167105956773854,
#  'mg': 0.14074855034264627,
#  '늘': 0.14061676331049025,
#  '오메가': 0.14022140221402213,
#  '피곤': 0.13877174486030575,
#  '있': 0.13877174486030575,
#  '이번': 0.13692672641012124,
#  '식품': 0.1335002635740643,
#  '개선': 0.13336847654190828,
#  '가성': 0.13205060622034792,
#  '우루': 0.1283605693199789,
#  '미네랄': 0.12796520822351082,
#  '부담': 0.12677912493410648,
#  '때문': 0.12638376383763839,
#  '냄새': 0.12282551396942541,
#  '자주': 0.12216657880864523,
#  '밀크': 0.12177121771217712,
#  '판매': 0.0632577754348972,
#  '문제': 0.0628624143384291,
#  '염증': 0.0628624143384291,
#  '원료': 0.06273062730627306,
#  '보조': 0.06233526620980496,
#  '평소': 0.06220347917764892,
#  '보호': 0.061808118081180814,
#  '음식': 0.061808118081180814,
#  '저렴': 0.06154454401686874,
#  '로켓': 0.06154454401686874,
#  '체내': 0.06154454401686874,
#  '세포': 0.061149182920400634,
#  '보충': 0.060753821823932526,
#  '보다': 0.06062203479177649,
#  '구성': 0.059435951502372165,
#  '대비': 0.05930416447021613,
#  '미리': 0.05759093305218767,
#  '경우': 0.05719557195571956,
#  '노화': 0.05693199789140749,
#  '수치': 0.0558777016341592,
#  '부모': 0.05574591460200316,
#  '변화': 0.055350553505535055,
#  '생활': 0.05521876647337902,
#  '폴리스': 0.05521876647337902,
#  '부분': 0.05495519240906695,
#  '친구': 0.05495519240906695,
#  '컨디션': 0.05482340537691091,
#  '주일': 0.05455983131259884,
#  '관절': 0.05376910911966262,
#  '중요': 0.053637322087506586,
#  '제로': 0.05350553505535055,
#  '도착': 0.05324196099103848,
#  '제일': 0.05284659989457038,
#  '점점': 0.05284659989457038,
#  '기존': 0.052583025830258305,
#  '체험': 0.05231945176594623}

# %%
import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.axis('off') 
plt.show()

# %% [markdown]
# ###### 문장을 합쳐서 계산할때

# %%
text = ' '.join(df_recovery['mecab_reviews'])
text
# Out:
# '피곤 느낌 물 삼키 고요 복용 한지 얼마 피로 회복 증강 좋 함량 품질 좋 제품 구매 항상 부분 한약 체력 도움 부원 성분 신경 업무 강도 인지 입맛 구매 성분 함량 알약 타입 먹 크기 넘김 코로나 확진 떨어지 컨디션 블랙 마카 남자 특화 양제 성분 흑마 늘 아르기닌 관문 좋 기운 기력 남편 구매 캡슐 타입 먹 신랑 복용 좋 아르기닌 흑마 늘 마카 성분 한마디 가격 효과 이나 탄복 여기저기 선물 운전 남편 주문 회사 블랙 마카 이번 첨가 한번 보 배송 요새 구입 성분 원료 섭취 넘김 블랙 마카 아침 알 지금 피곤 느낌 남편 아르기닌 남자 흑마 늘 대안 먹 사람 먹 대요 가격 부모 구매 효능 기력 회복 도움 개월 보 사용 후기 포장 상태 안 먹 차이 하루 시간 비교 하 만해 남편 건강 구매 좋 성분 인증 받 제품 크기 넘김 주문 신랑 남동생 아빠 섭취 개월 효과 미미 언제 캡슐 박스 남편 양제 걱정 넘김 먹 워낙 남자 성분 야근 자주 아침 알약 먹 성분 배송 도착 블랙 마카 분말 함유 캡슐 박스 당분간 가성 계속 복용 건강 좋 남편 남자 블랙 마카 구매 여러 가지 괜찬은거 먹 아침 컨디션 좋  피곤 성분  가격 대비 블랙 마카 빠르 배송 꼼꼼 포장 굿 대박 국내 좋 안구 건조 증도 무엇 신랑 운전 직업 항상 피곤 주문 먹 알약 단점 유통 기한 구입 배송 이번 박스 포장 케이스 상태 양호 직구 주문 기전 제품 복용
핸드폰 컴퓨터 자제 야하 시력 보호 안경 착용 도수 없 블루 라이트 차단 가려움 섭취 변현 얼굴 폐암 발병 위험 최대 준치 초창 함량 도움 하루 아침 부쩍 황달 양제 있 도대체 문제 하나 체크 모든 실천 작 습관 잘못 기전 검색 과유 불급 캡슐 할인 기간 지금 가격 다시 쟁여 잔틴 함유 되 추가 후기 사진 변질 동안 오다 산패 사방 튀 난리 연말 이번 호구 회사 소량 대한 설명 칭찬 아니 내용 그대로 일부러 포함 가장 상단 좋 보 상품 페이지 스마트 필터 별로 찾아보 기분 색깔 마음 닥터스 베스트 멀티 비타민 함량 때문 mg 주문 이번 구입 가격 계산 루테인 제아 잔틴 효과 상태 섭취 제품 정도 건강 관심 생각 정보 Meso zeaxanthin 황반 노란색 물질 하나 가지 색소 MP 가장 중앙 집중 되 반면 Lutein 말초 분포 Zeaxanthin 카로티노이드 조합 우수 항산 능력 연구 의사 시력 자원 봉사자 AMD 환자 대상 높 농도 달성 복용량 수준 테스트 일정 ...

# %%
# 단어로 쪼개기 
text_split = text.split()

# %%
# counter를 이용해서 중복 여부 count
from collections import Counter
Counter(text_split)
# Out:
# Counter({'피곤': 1053,
#          '느낌': 1463,
#          '물': 1149,
#          '삼키': 112,
#          '고요': 117,
#          '복용': 3341,
#          '한지': 315,
#          '얼마': 231,
#          '피로': 1525,
#          '회복': 1082,
#          '증강': 71,
#          '좋': 4248,
#          '함량': 1158,
#          '품질': 219,
#          '제품': 5003,
#          '구매': 6118,
#          '항상': 892,
#          '부분': 417,
#          '한약': 39,
#          '체력': 613,
#          '도움': 2990,
#          '부원': 191,
#          '성분': 2488,
#          '신경': 671,
#          '업무': 116,
#          '강도': 22,
#          '인지': 499,
#          '입맛': 108,
#          '알약': 2350,
#          '타입': 262,
#          '먹': 5528,
#          '크기': 1960,
#          '넘김': 1372,
#          '코로나': 307,
#          '확진': 48,
#          '떨어지': 64,
#          '컨디션': 416,
#          '블랙': 173,
#          '마카': 281,
#          '남자': 256,
#          '특화': 13,
#          '양제': 3482,
#          '흑마': 48,
#          '늘': 1067,
#          '아르기닌': 186,
#          '관문': 31,
#          '기운': 225,
#          '기력': 158,
#          '남편': 1103,
#          '캡슐': 1235,
#          '신랑': 746,
#          '한마디': 19,
#          '가격': 4583,
#          '효과': 4778,
#          '이나': 58,
#          '탄복': 8,
#          '여기저기': 149,
#          '선물': 1075,
#          '운전': 61,
#          '주문': 2389,
#          '회사': 703,
#          '이번': 1039,
#          '첨가': 161,
#          '한번': 269,
#          '보': 2731,
#          '배송': 7588,
#          '요새': 137,
#          '구입': 1965,
#          '원료': 476,
#          '섭취': 2822,
#          '아침': 1527,
#          '알': 279,
#          '지금': 767,
#          '대안': 20,
#          '사람': 1186,
#          '대요': 88,
#          '부모': 423,
#          '효능': 915,
#          '개월': 1083,
#          '사용': 640,
#          '후기': 2156,
#          '포장': 3151,
#          '상태': 2137,
#          '안': 2460,
#          '차이': 606,
#          '하루': 2262,
#          '시간': 643,
#          '비교': 514,
#          '하': 3105,
#          '만해': 32,
#          '건강': 4080,
#          '인증': 181,
#          '받': 294,
#          '남동생': 32,
#          '아빠': 161,
#          '미미': 12,
#          '언제': 94,
#          '박스': 780,
#          '걱정': 811,
#          '워낙': 360,
#          '야근': 173,
#          '자주': 927,
#          '도착': 404,
#          '분말': 220,
#          '함유': 807,
#          '당분간': 85,
#          '가성': 1002,
#          '계속': 262,
#          '여러': 874,
#          '가지': 1624,
#          '괜찬은거': 10,
#          '대비': 450,
#          '빠르': 370,
#          '꼼꼼': 25,
#          '굿': 272,
#          '대박': 61,
#          '국내': 324,
#          '안구': 84,
#          '건조': 337,
#          '증도': 23,
#          '무엇': 348,
#          '직업': 74,
#          '단점': 288,
#          '유통': 6588,
#          '기한': 6579,
#          '케이스': 96,
#          '양호': 19,
#          '직구': 620,
#          '기전': 147,
#          '뇌출혈': 3,
#          '가': 307,
#          '종합': 683,
#          '병원': 494,
#          '진로': 1,
#          '검사': 203,
#          '진료': 39,
#          '최소': 90,
#          '밀리': 9,
#          '본인': 120,
#          '스마일': 5,
#          '라섹': 42,
#          '이후': 277,
#          '장거리': 5,
#          '운정': 1,
#          '나': 89,
#          '졋다': 6,
#          '보조': 473,
#          '마법': 10,
#          '덜하': 7,
#          '마사지': 8,
#          '기계': 8,
#          '도사': 1,
#          '전보': 99,
#          '끄': 13,
#          '마음': 710,
#          '오른쪽': 18,
#          '머리': 225,
#          '약사': 134,
#          '복전': 4,
#          '던데': 38,
#          '바슈': 1,
#          '바이트': 7,
#          '적극': 171,
#          '추천': 1748,
#          '뻑뻑': 170,
#          '오메가': 1064,
#          '베리': 104,
#          '추출': 592,
#          '비타민': 4546,
#          '하나': 1240,
#          '상품': 1372,
#          '평보': 20,
#          '어디': 191,
#          '볼': 3,
#          '지난': 90,
#          '유효': 71,
#          '기간': 285,
#          '짧': 26,
#          '물건': 69,
#          '멘붕': 1,
#          '노란색': 58,
#          '갑자기': 265,
#          '용량': 774,
#          '인진': 2,
#          '아연': 879,
#          '때문': 959,
#          '자': 379,
#          '제일': 401,
#          '미국': 166,
#          '출장': 55,
#          '쿠팡': 1270,
#          '꼬박': 45,
#          '깜빡': 66,
#          '완화': 328,
#          '전체': 51,
#          '챙켜': 1,
#          '다시': 1085,
#          '광고': 327,
#          '무난': 73,
#          '최고': 367,
#          '상시': 6,
#          '패키지': 185,
#          '디자인': 66,
#          '예정': 370,
#          '외국': 65,
#          '사다': 2,
#          '비닐': 104,
#          '처음': 647,
#          '실링': 6,
#          '추석': 40,
#          '서요': 19,
#          '설명': 295,
#          '야하': 167,
#          '이구': 16,
#          '대체': 60,
#          '임박': 34,
#          '그랬': 1,
#          '도안': 27,
#          '얼른': 74,
#          '환불': 16,
#          '진짜': 132,
#          '팔': 17,
#          '심지어': 2,
#          '기다': 38,
#          '확인': 291,
#          '판매': 480,
#          '리뷰': 1122,
#          '프로': 576,
#          '실제': 153,
#          '노안': 163,
#          '예상': 36,
#          '발악': 1,
#          '수준': 148,
#          'mg': 1068,
#          '국내외': 2,
#          '되': 1838,
#          '봣는데': 1,
#          '뉴스': 16,
#          '네이버': 39,
#          '메인': 12,
#          '반변': 40,
#          '증상': 739,
#          '있': 1053,
#          '높': 260,
#          '바보': 4,
#          '행동': 12,
#          '나우': 283,
#          '아틴': 1,
#          '거의': 82,
#          '불': 45,
#          '루테인': 146,
#          '지아': 342,
#          '잔틴': 489,
#          '생각': 2494,
#          '적격': 1,
#          '시기': 153,
#          '중간': 103,
#          '흡수': 758,
#          '위해': 1188,
#          '필수': 651,
#          '어렵': 57,
#          '의학': 18,
#          '자료': 19,
#          '염려': 56,
#          '스탈': 4,
#          '자다': 540,
#          '보이': 155,
#          '아무렇': 39,
#          '오늘': 325,
#          '평범': 12,
#          '브랜드': 523,
#          '서울': 8,
#          '기준': 297,
#          '파손': 64,
#          '문제': 477,
#          '없': 923,
#          '제아': 31,
#          '한국': 64,
#          '저렴': 467,
#          '한편': 71,
#          '런가': 135,
#          '도하': 22,
#          '필요': 1403,
#          '영양분': 71,
#          '리트': 3,
#          '가족': 642,
#          '닥터': 233,
#          '베스트': 279,
#          '만족': 481,
#          '스럽': 119,
#          '식이': 230,
#          '보충': 461,
#          '대두': 19,
#          '포함': 506,
#          '각막': 14,
#          '축적': 49,
#          '카로티노이드': 15,
#          '제라': 85,
#          '마리': 81,
#          '골드': 223,
#          '제공': 553,
#          '노화': 432,
#          '시력': 275,
#          '감퇴': 42,
#          '내장': 78,
#          '예방': 526,
#          '수용체': 6,
#          '지방산': 49,
#          '산화': 190,
#          '방지': 231,
#          '망막': 97,
#          '주변': 315,
#          '공급': 101,
#          '혈관': 241,
#          '억제': 136,
#          '역할': 260,
#          '감소': 386,
#          '황반': 191,
#          '색소': 153,
#          '밀도': 158,
#          '유지': 632,
#          '카로': 1,
#          '노이드': 1,
#          '일종': 23,
#          '항산화제': 42,
#          '기능': 1106,
#          '녹내장': 13,
#          '연구': 101,
#          '재단': 1,
#          '스트레스': 384,
#          '시신경': 1,
#          '손상': 172,
#          '연관': 13,
#          '같': 1316,
#          '질환': 306,
#          '물질': 290,
#          '짙': 9,
#          '녹색': 47,
#          '잎채소': 7,
#          '채소': 71,
#          '영양': 1557,
#          '질산염': 1,
#          '브로콜리': 32,
#          '양배추': 18,
#          '옥수수': 81,
#          '케일': 12,
#          '배추': 7,
#          '상추': 8,
#          '호박': 9,
#          '달걀': 13,
#          '나이': 1397,
#          '크': 647,
#          '불편': 215,
#          '침침': 72,
#          '보정': 4,
#          '안경': 82,
#          '번갈': 48,
#          '착용': 43,
#          '현실': 18,
#          '앞전': 28,
#          '비타': 89,
#          '이뮨': 43,
#          '해도': 278,
#          '여력': 2,
#          '녀석': 66,
#          '미치': 48,
#          '닥터스': 177,
#          '선택': 881,
#          '계기': 41,
#          '어깨': 94,
#          '통증': 327,
#          '에스': 10,
#          '어가': 2,
#          '결정': 204,
#          '소프트': 89,
#          '종류': 395,
#          '그대로': 137,
#          '리언': 5,
#          '자체': 226,
#          '지용성': 121,
#          '이기': 212,
#          '사실': 178,
#          '취향': 27,
#          '가능': 231,
#          '장점': 264,
#          '들': 189,
#          '잡': 96,
#          '심정': 31,
#          '컴퓨터': 180,
#          '편입': 176,
#          '웃기': 3,
#          '취미': 8,
#          '게임': 30,
#          '놀이': 11,
#          '알레르기': 131,
#          '결막염': 26,
#          '염증': 477,
#          '깜박이': 1,
#          '다급': 1,
#          '상황': 94,
#          '깜박': 26,
#          '거리': 115,
#          '피안': 1,
#          '보스': 136,
#          '희생': 3,
#          '수많': 31,
#          '에픽': 1,
#          '아이템': 43,
#          '빨갛': 9,
#          '눈곱': 19,
#          '생기': 310,
#          '크다': 136,
#          '추가': 691,
#          '토마토': 18,
#          '색깔': 118,
#          '안토시아닌': 13,
#          '흰자위': 4,
#          'Zeaxanthin': 5,
#          '청색': 19,
#          '의하': 49,
#          '보호': 469,
#          '변성': 39,
#          '위험': 177,
#          '실명': 5,
#          '심장병': 40,
#          '뇌졸증': 4,
#          '행성': 21,
#          'Lutein': 9,
#          '심장': 166,
#          '항산': 644,
#          '지원': 46,
#          '기억': 316,
#          '향상': 204,
#          '대장암': 12,
#          '유방암': 15,
#          '당뇨병': 71,
#          '중심': 80,
#          '발견': 213,
#          '화합물': 35,
#          '농도': 57,
#          '베타카로틴': 5,
#          'EPA': 78,
#          'DHA': 80,
#          'Anthocyanin': 2,
#          'IU': 83,
#          '최대': 101,
#          '아스타': 103,
#          'Astaxanthin': 2,
#          '안구건조증': 101,
#          '칼륨': 22,
#          '이유': 731,
#          '로켓': 467,
#          '영어': 38,
#          '표기': 90,
#          '사시': 26,
#          '잘못': 171,
#          '정보': 206,
#          '사': 572,
#          '부작용': 534,
#          '일어나': 243,
#          '방치': 37,
#          '팔랑': 10,
#          '올바르': 26,
#          '인터넷': 156,
#          '영양학': 12,
#          '약학': 12,
#          '참고': 525,
#          '주로': 169,
#          '가장': 655,
#          '상관': 60,
#          '생소': 12,
#          '검색': 757,
#          '여러분': 177,
#          '계시': 119,
#          '수명': 28,
#          '연장': 14,
#          '음식': 469,
#          '영양소': 675,
#          '각각': 25,
#          '시너지': 119,
#          '하버드': 1,
#          '블루': 11,
#          '라이트': 33,
#          '대처': 19,
#          '방법': 356,
#          '유해': 256,
#          '광선': 27,
#          '시스템': 50,
#          '수정체': 8,
#          '주기': 101,
#          '화면': 26,
#          '집중': 168,
#          '횟수': 61,
#          '평소': 472,
#          '이하': 34,
#          '눈물': 95,
#          '증발': 2,
#          '증가': 162,
#          '증세': 74,
#          '기기': 62,
#          '멀': 14,
#          '모니터': 48,
#          '경우': 434,
#          '야간': 45,
#          '조명': 4,
#          '두운': 45,
#          '적색': 1,
#          '차단': 39,
#          '붉': 21,
#          '리듬': 5,
#          '멜라토닌': 15,
#          '적다': 41,
#          '전자': 59,
#          '수면': 154,
#          '방해': 78,
#          '근무': 67,
#          '거나': 97,
#          '많': 843,
#          '장치': 8,
#          '파란색': 6,
#          '파장': 1,
#          '필터': 3,
#          '응용': 1,
#          '프로그램': 14,
#          '설치': 10,
#          '햇빛': 155,
#          '노출': 88,
#          '기분': 704,
#          '주의력': 2,
#          '할인': 214,
#          '쿠폰': 72,
#          '적용': 41,
#          '기회': 113,
#          '금액': 106,
#          '루트': 8,
#          '차례': 11,
#          '맥스': 38,
#          '스마트폰': 112,
#          '날짜': 120,
#          '수령': 49,
#          '세계': 51,
#          '이슈': 9,
#          '공지': 6,
#          '특성': 80,
#          '장시간': 38,
#          '남지': 17,
#          '이용': 307,
#          '불안감': 5,
#          '금보': 3,
#          '기존': 399,
#          '목구멍': 112,
#          '조금': 818,
#          '식도': 30,
#          '시작': 1120,
#          '시야': 24,
#          '답답': 12,
#          '정도': 1604,
#          '지장': 42,
#          '공부': 104,
#          '공유': 40,
#          '운동': 806,
#          '스트레칭': 7,
#          '좌측': 1,
#          '우측': 3,
#          '위쪽': 16,
#          '아래': 69,
#          '고개': 17,
#          '눈알': 8,
#          '움직': 14,
#          '마무리': 40,
#          '회전': 5,
#          '역시': 387,
#          '마찬가지': 34,
#          '구석구석': 4,
#          '시계': 10,
#          '방향': 7,
#          '반대': 18,
#          '저녁': 686,
#          '따뜻': 32,
#          '초과': 36,
#          '핸드폰': 102,
#          '자제': 27,
#          '도수': 2,
#          '가려움': 24,
#          '변현': 1,
#          '얼굴': 367,
#          '폐암': 15,
#          '발병': 27,
#          '준치': 100,
#          '초창': 6,
#          '부쩍': 111,
#          '황달': 10,
#          '도대체': 9,
#          '체크': 94,
#          '모든': 352,
#          '실천': 14,
#          '작': 830,
#          '습관': 243,
#          '과유': 17,
#          '불급': 17,
#          '쟁여': 74,
#          '사진': 368,
#          '변질': 102,
#          '동안': 263,
#          '오다': 41,
#          '산패': 34,
#          '사방': 4,
#          '튀': 5,
#          '난리': 39,
#          '연말': 38,
#          '호구': 8,
#          '소량': 88,
#          '대한': 247,
#          '칭찬': 23,
#          '아니': 283,
#          '내용': 121,
#          '일부러': 48,
#          '상단': 8,
#          '페이지': 32,
#          '스마트': 15,
#          '별로': 367,
#          '찾아보': 14,
#          '멀티': 903,
#          '계산': 42,
#          '관심': 226,
#          'Meso': 1,
#          'zeaxanthin': 2,
#          'MP': 1,
#          '중앙': 2,
#          '반면': 12,
#          '말초': 4,
#          '분포': 15,
#          '조합': 85,
#          '우수': 38,
#          '능력': 107,
#          '의사': 614,
#          '자원': 1,
#          '봉사자': 1,
#          'AMD': 2,
#          '환자': 84,
#          '대상': 58,
#          '달성': 2,
#          '복용량': 49,
#          '테스트': 29,
#          '일정': 63,
#          '그룹': 13,
#          '혈중': 119,
#          '모두': 201,
#          '결론': 95,
#          '실험': 41,
#          '결과': 388,
#          '단어': 14,
#          '두렵': 3,
#          '소중': 84,
#          '동기': 181,
#          '어머님': 67,
#          '안다': 5,
#          '꼬리': 11,
#          '반복': 57,
#          '피부': 1105,
#          '바람': 60,
#          '보안': 2,
#          '경이': 4,
#          '인상': 25,
#          '쓰시': 9,
#          '달라': 200,
#          '주름': 92,
#          '어머니': 169,
#          '노인': 20,
#          '한중': 2,
#          '방송': 56,
#          '보시': 170,
#          '이야기': 190,
#          '싫': 61,
#          '부탁': 43,
#          '약국': 376,
#          '전이': 57,
#          '제다': 9,
#          '만난': 10,
#          '주일': 414,
#          '이제': 324,
#          '이상': 728,
#          '신호': 43,
#          '자꾸': 261,
#          '아버지': 79,
#          '저희': 103,
#          '행복': 92,
#          '표정': 7,
#          '죄송': 19,
#          '이전': 187,
#          '글루텐': 39,
#          '프리': 44,
#          'Non': 10,
#          'GMO': 21,
#          '구성원': 8,
#          '교정술': 3,
#          '꼬박꼬박': 159,
#          '바구니': 2,
#          '한눈': 36,
#          '꼭대기': 1,
#          '이름': 168,
#          'Vt': 2,
#          '구성': 451,
#          '로써': 72,
#          '대가': 96,
#          '절반': 38,
#          '최근': 219,
#          '환경': 68,
#          '변화': 420,
#          '가속': 12,
#          '고갈': 3,
#          '부족': 524,
#          '다양': 377,
#          '발생': 189,
#          '확률': 33,
#          '라식': 47,
#          '어떻': 302,
#          '이렇': 110,
#          '뚜껑': 162,
#          '서예': 1,
#          '아가': 13,
#          '가정': 34,
#          '성인': 200,
#          '오픈': 26,
#          '그렇': 486,
#          '과정': 114,
#          '선호': 88,
#          '제도': 249,
#          '관리': 877,
#          'got': 4,
#          'my': 5,
#          'eyesight': 1,
#          'corrected': 1,
#          'So': 5,
#          'to': 6,
#          'help': 3,
#          'your': 3,
#          'eyes': 5,
#          'take': 8,
#          'lutein': 1,
#          'Whatever': 1,
#          'nutritional': 3,
#          'Wow': 1,
#          'the': 5,
#          'effects': 3,
#          'are': 7,
#          'best': 6,
#          'can': 3,
#          'really': 3,
#          'feel': 3,
#          'things': 1,
#          'like': 3,
#          'this': 5,
#          'But': 2,
#          'love': 1,
#          'Dr': 1,
#          'Best': 6,
#          'supplement': 2,
#          'The': 7,
#          'because': 1,
#          'you': 3,
#          'open': 3,
#          'lid': 2,
#          'easily': 1,
#          're': 3,
#          'all': 2,
#          'grown': 1,
#          'ups': 1,
#          'And': 3,
#          'first': 1,
#          'of': 15,
#          'and': 14,
#          'it': 7,
#          'out': 1,
#          'easy': 1,
#          'Of': 1,
#          'course': 1,
#          'there': 1,
#          'supplements': 3,
#          'care': 3,
#          'ourselves': 1,
#          'in': 10,
#          'healthy': 4,
#          'will': 1,
#          'be': 1,
#          'difference': 1,
#          'between': 1,
#          'eating': 3,
#          'not': 3,
#          'Personally': 1,
#          'reason': 1,
#          'is': 6,
#          'simple': 1,
#          'It': 5,
#          'Haha': 2,
#          'Families': 1,
#          'with': 5,
#          'young': 1,
#          'babies': 1,
#          'could': 1,
#          'little': 1,
#          'dangerous': 1,
#          'We': 1,
#          'prefer': 1,
#          'from': 4,
#          'other': 3,
#          'brands': 3,
#          'Our': 1,
#          'precious': 1,
#          'Let': 3,
#          'Thank': 3,
#          'for': 11,
#          'reading': 3,
#          'long': 4,
#          'comment': 3,
#          'hope': 3,
#          'helped': 3,
#          'choose': 3,
#          '정말': 1236,
#          '과일': 142,
#          '야채': 86,
#          '식물': 292,
#          '빨간색': 10,
#          '주황색': 14,
#          '우리': 368,
#          '반응': 201,
#          '통제': 6,
#          '장기': 114,
#          '중화': 10,
#          '자연': 146,
#          '위치': 34,
#          '인체': 134,
#          '제로': 406,
#          '권장': 254,
#          '이점': 7,
#          '전하': 91,
#          '간주': 8,
#          '독성': 40,
#          '안심': 243,
#          '아쉬움': 27,
#          '사랑': 123,
#          '신체': 190,
#          '기관': 43,
#          '담당': 75,
#          '자극': 75,
#          '외부': 110,
#          '요인': 78,
#          '심부': 42,
#          '존재': 114,
#          '체내': 467,
#          '자동': 10,
#          '합성': 314,
#          '비율': 141,
#          '간혹': 76,
#          '이루어지': 4,
#          '장복': 34,
#          '분량': 136,
#          '거기': 176,
#          '황금': 27,
#          '희': 33,
#          '자위': 1,
#          '검': 29,
#          '최적': 11,
#          '속도': 105,
#          '시럭': 1,
#          '아이': 504,
#          '먹이': 87,
#          '쓰': 140,
#          '나파': 1,
#          '부담': 962,
#          '소요': 16,
#          '가량': 34,
#          '식품': 1013,
#          '시금치': 25,
#          '당근': 37,
#          '용법': 150,
#          '장량': 290,
#          '식사': 581,
#          '칼슘': 523,
#          '마그네슘': 510,
#          '미네랄': 971,
#          '생체': 21,
#          '시키': 140,
#          '교정': 8,
#          '수술': 183,
#          '제약': 530,
#          '메리': 5,
#          '활성산소': 115,
#          '일찍': 132,
#          '통틀어': 2,
#          '매달': 35,
#          '용기': 62,
#          '적당': 169,
#          '서랍': 22,
#          '공간': 10,
#          '차지': 31,
#          '지인': 593,
#          '조그만': 5,
#          '조직': 173,
#          '저하': 172,
#          '개선': 1012,
#          '점차': 46,
#          '생산': 94,
#          '로부터': 323,
#          '배합': 123,
#          '티비': 73,
#          '저기': 7,
#          '나쁘': 99,
#          '자동차': 1,
#          '보험': 20,
#          '실력': 1,
#          '고명': 3,
#          '박사': 109,
#          '석사': 1,
#          '학사': 1,
#          '권사': 1,
#          '주술사': 1,
#          '밤낮': 9,
#          '싸': 33,
#          '현미경': 2,
#          '장갑': 2,
#          '끼': 20,
#          '핀셋': 1,
#          '비커': 1,
#          '반대편': 1,
#          '투명': 41,
#          '화이트': 11,
#          '보드': 1,
#          '탄소': 9,
#          '연결': 2,
#          '고리': 1,
#          '알파벳': 1,
#          '면서': 54,
#          '훌륭': 31,
#          '사고': 65,
#          '신도': 1,
#          '구비': 34,
#          '개입': 111,
#          '넉넉': 49,
#          '사이즈': 590,
#          '서로': 36,
#          '보관': 286,
#          '강화': 262,
#          '디지털': 1,
#          '요량': 43,
#          'Doctor': 6,
#          'BEST': 5,
#          '인하': 162,
#          '그중': 75,
#          '괜찮': 551,
#          '재료': 127,
#          '출처': 10,
#          '분명': 56,
#          'OmniActive': 1,
#          'Lutemax': 1,
#          '관련': 105,
#          '어떠': 22,
#          '옴니': 1,
#          '액티브': 2,
#          '공식': 4,
#          '홈페이지': 20,
#          '편의': 17,
#          '고려': 311,
#          '나빠': 29,
#          '부위': 26,
#          '위함': 11,
#          '젊': 128,
#          '요즘': 540,
#          '시대': 68,
#          '역활': 28,
#          '발췌': 2,
#          '중심부': 13,
#          '종일': 138,
#          '출퇴근': 12,
#          '혹사': 27,
#          '새롭': 50,
#          '꼽': 19,
#          '는다': 1,
#          '래핑': 1,
#          '밀봉': 52,
#          '비밀': 3,
#          '제거': 156,
#          '실망': 14,
#          '대략': 55,
#          '청춘': 3,
#          '안쪽': 25,
#          '경련': 31,
#          '부랴부랴': 17,
#          '순간': 107,
#          '사이': 99,
#          '먼저': 223,
#          '급속도': 2,
#          '베스': 2,
#          '트루': 3,
#          '기도': 502,
#          '고량': 6,
#          '질병': 125,
#          '읫사': 1,
#          '권고': 11,
#          '차원': 106,
#          ...})

# %%
# 한글 폰트 경로 설정 (Windows 환경에 맞게 경로 수정)
font_path = 'C:/Windows/Fonts/malgun.ttf'

wordCloud = WordCloud(font_path=font_path, background_color='white') #인스턴스화 
wordCloud.generate_from_text(text)

# %%
# count 
wordCloud.words_
# Out:
# {'유통 기한': 1.0,
#  '성능 유통': 0.5039938556067588,
#  '배송 성능': 0.46912442396313364,
#  '효과': 0.34147465437788016,
#  '제품': 0.3170506912442396,
#  '먹': 0.3012288786482335,
#  '복용': 0.2645161290322581,
#  '생각': 0.25099846390168973,
#  '포장 상태': 0.2411674347158218,
#  '구매': 0.23640552995391706,
#  '기한 배송': 0.22242703533026115,
#  '하': 0.22119815668202766,
#  '배송 보통': 0.22089093701996929,
#  '가격 배송': 0.20937019969278034,
#  '양제': 0.20583717357910905,
#  '기한 포장': 0.2023041474654378,
#  '좋': 0.1976958525345622,
#  '섭취': 0.1642089093701997,
#  '주문': 0.14208909370199693,
#  '정도': 0.1356374807987711,
#  '구입': 0.13317972350230414,
#  '도움': 0.1302611367127496,
#  '정말': 0.12734254992319508,
#  '보통 유통': 0.1228878648233487,
#  '보': 0.11597542242703533,
#  '비타민': 0.11597542242703533,
#  '보통 성능': 0.1064516129032258,
#  '추천': 0.09907834101382489,
#  '하루': 0.09877112135176651,
#  '하나': 0.09708141321044547,
#  '건강': 0.09615975422427035,
#  '피로 회복': 0.09523809523809523,
#  '안': 0.09477726574500768,
#  '멀티 비타민': 0.0944700460829493,
#  '있': 0.09216589861751152,
#  '배송 가격': 0.09109062980030722,
#  '여러 가지': 0.08540706605222734,
#  '알약 크기': 0.08202764976958525,
#  '느낌': 0.0815668202764977,
#  '때문': 0.08064516129032258,
#  '사람': 0.07849462365591398,
#  '용량': 0.07665130568356375,
#  '브랜드': 0.034869431643625194,
#  '자주': 0.034715821812596005,
#  '시작': 0.034715821812596005,
#  '체험 이벤트': 0.034715821812596005,
#  '건강 위해': 0.03456221198156682,
#  '보통 포장': 0.03456221198156682,
#  '나우 푸드': 0.034408602150537634,
#  '좋 제품': 0.033947772657450075,
#  '걱정': 0.03333333333333333,
#  '참고': 0.03333333333333333,
#  '제일': 0.03317972350230415,
#  '흡수': 0.03271889400921659,
#  '크': 0.03271889400921659,
#  '건강 관리': 0.03271889400921659,
#  '면역': 0.03210445468509985,
#  '요즘': 0.03179723502304147,
#  '실리 마린': 0.03179723502304147,
#  '안 되': 0.03164362519201229,
#  '알약 먹': 0.03118279569892473,
#  '피로 개선': 0.031029185867895544,
#  '최고': 0.030721966205837174,
#  '아이': 0.030721966205837174,
#  '만족': 0.030568356374807988,
#  '효과 배송': 0.030568356374807988,
#  '효과 보': 0.030107526881720432,
#  '저녁': 0.029953917050691243,
#  '후기': 0.029800307219662057,
#  '워낙': 0.029800307219662057,
#  '병원': 0.029646697388632872,
#  '나이': 0.029646697388632872,
#  '아니': 0.029185867895545316,
#  '부모': 0.02903225806451613,
#  '예정': 0.02903225806451613,
#  '경우': 0.02903225806451613,
#  '선물': 0.028878648233486945,
#  '종근당 건강': 0.028725038402457756,
#  '평소': 0.0282642089093702,
#  '안 먹': 0.0282642089093702,
#  '구매 효과': 0.02795698924731183,
#  '리뷰': 0.027803379416282643,
#  '차이': 0.027649769585253458,
#  '시간': 0.02749615975422427,
#  '단점': 0.027342549923195084,
#  '구매 가격': 0.027342549923195084,
#  '영양 제도': 0.027035330261136713,
#  '양제 구매': 0.026881720430107527,
#  '건강 식품': 0.026881720430107527,
#  '보다': 0.02642089093701997,
#  '무엇': 0.026113671274961597,
#  '자꾸': 0.026113671274961597,
#  '가루': 0.026113671274961597,
#  '작성 후기': 0.026113671274961597,
#  '빠르 배송': 0.02596006144393241,
#  '지인 추천': 0.02596006144393241,
#  '항산 작용': 0.02596006144393241,
#  '주일': 0.025806451612903226,
#  '나이 아신': 0.025806451612903226,
#  '유해 산소': 0.025806451612903226,
#  '확인': 0.02565284178187404,
#  '로켓 배송': 0.02565284178187404,
#  '저렴 가격': 0.02565284178187404,
#  '다이어트': 0.025499231950844855,
#  '닥터스 베스트': 0.025499231950844855,
#  '별로': 0.02534562211981567,
#  '효과 좋': 0.025192012288786484,
#  '금방': 0.024731182795698924,
#  '세포 보호': 0.024731182795698924,
#  '부족': 0.02457757296466974,
#  '가성 좋': 0.02457757296466974,
#  '구매 이유': 0.02457757296466974,
#  '콜라겐': 0.024270353302611368,
#  '보조 식품': 0.024116743471582183,
#  '저렴': 0.023963133640552997,
#  '부분': 0.023809523809523808,
#  '장점': 0.023809523809523808,
#  '주문 배송': 0.023809523809523808}

# %%
import matplotlib.pyplot as plt
plt.imshow(wordCloud)
plt.axis('off') 
plt.show()

# %% [markdown]
# ### 벡터화 진행
